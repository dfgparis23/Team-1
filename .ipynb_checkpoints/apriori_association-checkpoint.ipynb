# %%
import pandas as pd
from mlxtend.frequent_patterns import association_rules
FILE_PATH = "../shared_data_read_only/"
FILES = ("consumer_price_index.xlsx","Contacts.xlsx","Invoice and Opportunities.xlsx",
         "Items and Opportunities.xlsx","Non-Stock Items.xlsx","Opportunities.xlsx")

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlxtend
#   Downloading mlxtend-0.23.0-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 23.7 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn in /opt/tljh/user/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (0.24.2)
# Collecting hmmlearn
#   Downloading hmmlearn-0.3.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (162 kB)
#      |████████████████████████████████| 162 kB 108.7 MB/s eta 0:00:01
# Requirement already satisfied: statsmodels in /opt/tljh/user/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (0.12.2)
# Requirement already satisfied: scipy in /opt/tljh/user/lib/python3.7/site-packages (from -r requirements.txt (line 5)) (1.6.3)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/tljh/user/lib/python3.7/site-packages (from mlxtend->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: joblib>=0.13.2 in /opt/tljh/user/lib/python3.7/site-packages (from mlxtend->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: numpy>=1.16.2 in /opt/tljh/user/lib/python3.7/site-packages (from mlxtend->-r requirements.txt (line 1)) (1.20.3)
# Requirement already satisfied: pandas>=0.24.2 in /opt/tljh/user/lib/python3.7/site-packages (from mlxtend->-r requirements.txt (line 1)) (1.2.4)
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.8 MB)
#      |████████████████████████████████| 24.8 MB 107.6 MB/s eta 0:00:01
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/tljh/user/lib/python3.7/site-packages (from scikit-learn->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/tljh/user/lib/python3.7/site-packages (from matplotlib>=3.0.0->mlxtend->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/tljh/user/lib/python3.7/site-packages (from matplotlib>=3.0.0->mlxtend->-r requirements.txt (line 1)) (8.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/tljh/user/lib/python3.7/site-packages (from matplotlib>=3.0.0->mlxtend->-r requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /opt/tljh/user/lib/python3.7/site-packages (from matplotlib>=3.0.0->mlxtend->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/tljh/user/lib/python3.7/site-packages (from matplotlib>=3.0.0->mlxtend->-r requirements.txt (line 1)) (2.4.7)
# Requirement already satisfied: six in /opt/tljh/user/lib/python3.7/site-packages (from cycler>=0.10->matplotlib>=3.0.0->mlxtend->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/tljh/user/lib/python3.7/site-packages (from pandas>=0.24.2->mlxtend->-r requirements.txt (line 1)) (2021.1)
# Requirement already satisfied: patsy>=0.5 in /opt/tljh/user/lib/python3.7/site-packages (from statsmodels->-r requirements.txt (line 4)) (0.5.1)
# Installing collected packages: scikit-learn, mlxtend, hmmlearn
# Successfully installed hmmlearn-0.3.0 mlxtend-0.23.0 scikit-learn-1.0.2

# %%
min_confidence = 0.7  # Définissez la confiance minimale souhaitée
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=min_confidence)

# %%
file_no = 3

df = pd.read_excel(f"{FILE_PATH}{FILES[file_no]}")
print(FILES[file_no])
df
# Out:
# Items and Opportunities.xlsx
#       Opportunity ID  Line Nbr. Inventory ID    Year  Unit Price  Quantity  \
# 0               6387        1.0      EVEN001  2023.0      9000.0       1.0
# 1               6386        1.0      EVEN001  2023.0      9000.0       1.0
# 2               6385        1.0       DONPAR  2023.0       140.0       1.0
# 3               6384        1.0       DONPAR  2023.0       350.0       1.0
# 4               6383        1.0       DONPAR  2023.0       120.0       1.0
# ...              ...        ...          ...     ...         ...       ...
# 7453               5        2.0      MECENAT  2021.0       209.0       1.0
# 7454               4        1.0      MECENAT  2020.0     10625.0       1.0
# 7455               3        1.0      MECENAT  2020.0     35000.0       1.0
# 7456               2        1.0      MECENAT  2020.0     20000.0       1.0
# 7457               1        1.0      MECENAT  2020.0     10000.0       1.0
#
#         UOM  Ext. Price Currency  Discount Amount  Discount, %  \
# 0     PIECE      9000.0      EUR              0.0          0.0
# 1     PIECE      9000.0      EUR              0.0          0.0
# 2     PIECE       140.0      EUR              0.0          0.0
# 3     PIECE       350.0      EUR              0.0          0.0
# 4     PIECE       120.0      EUR              0.0          0.0
# ...     ...         ...      ...              ...          ...
# 7453  PIECE       209.0      EUR              0.0          0.0
# 7454  PIECE      7500.0      EUR              0.0          0.0
# 7455  PIECE     35000.0      EUR              0.0          0.0
# 7456  PIECE     20000.0      EUR              0.0          0.0
# 7457  PIECE     10000.0      EUR              0.0          0.0
#
#               Funded Program Free Item Tax Category
# 0              Non specified     False         TVA0
# 1              Non specified     False         TVA0
# 2              Non specified     False         TVA0
# 3              Non specified     False         TVA0
# 4              Non specified     False         TVA0
# ...                      ...       ...          ...
# 7453           Non specified     False         TVA0
# 7454           Non specified     False            0
# 7455       Job dans la Ville     False            0
# 7456        Séjours et Camps     False            0
# 7457  Réussite dans la Ville     False            0
#
# [7458 rows x 14 columns]

# %%
df['Stage'].unique()
# Out:
# array(['Won', 'Oral agreement', 'Initial Prospect', 'Advanced Prospect',
#        'Lost', 'Dossier posed'], dtype=object)
