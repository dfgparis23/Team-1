# %% [markdown]
# # Basic Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_base = "../shared_data_read_only/"
data_base2 = "./data/final_data.csv"
files = ("Business Account.xlsx","consumer_price_index.xlsx","Contacts.xlsx","Invoice and Opportunities.xlsx","Opportunities.xlsx","Non-Stock Items.xlsx","Items and Opportunities.xlsx")

alldata = pd.read_csv(data_base2)
business_account = pd.read_excel(data_base+files[0])
consumer_prices = pd.read_excel(data_base+files[1])
contacts = pd.read_excel(data_base+files[2])
invoices = pd.read_excel(data_base+files[3])
opportunities = pd.read_excel(data_base+files[4])
nonstockitems = pd.read_excel(data_base+files[5])
itemsandopp = pd.read_excel(data_base+files[6])

# %%
business_account.head()
# Out:
#   Business Account Customer Status      Type Partner type    Class  \
# 0           C00001          Active  Customer      Partner  02FONDA
# 1           C00002          Active  Customer          NaN      NaN
# 2           C00003          Active  Customer          NaN      NaN
# 3           C00004          Active  Customer      Partner  01SIEGE
# 4           C00005          Active  Customer          NaN      NaN
#
#      Class Name                                    Activity sector  \
# 0    Foundation  HEALTH - SOCIAL - Social, Associations, Founda...
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3  Headquarters  BUSINESS ADMINISTRATION - Consulting, Audit, A...
# 4           NaN                                                NaN
#
#   Parent Business Account  Owner Name  Follow-up with Postal Code  \
# 0                     NaN         2.0             NaN       69009
# 1                     NaN        13.0             NaN       69005
# 2                     NaN         NaN             NaN           0
# 3                     NaN        12.0             NaN       75008
# 4                     NaN         NaN             NaN           0
#
#             City State Country ID Country Name              Created On  \
# 0           LYON   NaN         FR       France 2021-02-02 15:35:10.183
# 1           Lyon   NaN         FR       France 2021-02-02 15:35:11.213
# 2  Non renseigné   NaN         FR       France 2021-02-02 15:35:11.457
# 3          PARIS   NaN         FR       France 2021-02-02 15:35:11.770
# 4  Non renseigné   NaN         FR       France 2021-02-02 15:35:12.013
#
#          Last Modified On
# 0 2023-01-04 15:51:00.977
# 1 2021-03-24 16:25:28.393
# 2 2021-02-18 09:58:03.387
# 3 2023-08-03 11:08:03.953
# 4 2021-02-18 09:58:03.620

# %%
business_account.shape
# Out:
# (3483, 17)

# %%
consumer_prices.head()
# Out:
#         Date  consumer_price_index
# 0 2019-01-01                103.01
# 1 2019-02-01                103.06
# 2 2019-03-01                103.89
# 3 2019-04-01                104.22
# 4 2019-05-01                104.33

# %%
contacts.head()
# Out:
#    ContactID  Active Business Account      Class          Class Name  \
# 0      39405    True           C00091    01BUSIN   Business function
# 1      41938    True           C06932      03PDG                  DG
# 2      37775    True           C01438  10DIRGENE  General Management
# 3      37776    True           C01430      13ELU             Elected
# 4      36942    True           C01204      13ELU             Elected
#
#                                 Financing preference  Owner  Follow-up with  \
# 0                                                NaN   26.0             NaN
# 1  Apprenticeship tax, Gala Lyon, But en Or Lyon,...   29.0             NaN
# 2                                                NaN   17.0             8.0
# 3                                                NaN   17.0             8.0
# 4                                                NaN    6.0             5.0
#
#   Postal Code              City State Code pays  \
# 0    WC1V 6JS            London   NaN        GB
# 1       69120    VAULX EN VELIN   NaN        FR
# 2       93701            DRANCY   NaN        FR
# 3       93000           BOBIGNY   NaN        FR
# 4       69140  RILLIEUX-LA-PAPE   NaN        FR
#
#                                         Country Name Gender Client Source  \
# 0  United Kingdom of Great Britain and Northern I...    NaN           NaN
# 1                                             France    NaN           NaN
# 2                                             France   Male           NaN
# 3                                             France   Male           NaN
# 4                                             France   Male           NaN
#
#          Last Modified On              Created On
# 0 2023-07-11 14:37:02.183 2021-06-03 08:35:32.823
# 1 2023-02-07 12:19:14.043 2022-01-05 16:34:58.807
# 2 2021-03-23 07:05:02.557 2021-03-19 06:44:36.557
# 3 2021-03-23 07:05:03.410 2021-03-19 06:44:37.070
# 4 2021-04-13 10:52:53.050 2021-03-17 16:45:45.083

# %%
contacts.shape
# Out:
# (5511, 17)

# %%
invoices.head()
# Out:
#       Type Reference Nbr. Customer    Amount       Date  Opportunity ID
# 0  Invoice      FC0004608   C06507    5000.0 2023-10-10            4504
# 1  Invoice      FC0004607   C01388  241253.0 2023-10-09            1863
# 2  Invoice      FC0004605   C19104   83954.0 2023-10-06            5708
# 3  Invoice      FC0004600   C10528    3000.0 2023-06-23            5617
# 4  Invoice      FC0004598   C01196   54531.0 2023-10-09            5829

# %%
invoices.shape
# Out:
# (3238, 6)

# %%
opportunities.head()
# Out:
#    Opportunity ID Business Account  Contact ID Estimated Close Date Status  \
# 0            6387           C00037     35334.0           2023-11-27    New
# 1            6386           C01254     36240.0           2023-10-11    New
# 2            6385           C21512     47640.0           2023-10-11    New
# 3            6384           C21509     47636.0           2023-10-11    New
# 4            6383           C21508     47635.0           2023-10-10    New
#
#             Stage  Probability  Estimated amount  Amount received  Difference  \
# 0             Won          100            9000.0              NaN     -9000.0
# 1             Won          100            9000.0              NaN     -9000.0
# 2  Oral agreement           80             140.0              NaN      -140.0
# 3  Oral agreement           80             350.0              NaN      -350.0
# 4  Oral agreement           80             120.0              NaN      -120.0
#
#    ...  Theorical payment amount 3  Theorical payment date 4  \
# 0  ...                         NaN                       NaT
# 1  ...                         NaN                       NaT
# 2  ...                         NaN                       NaT
# 3  ...                         NaN                       NaT
# 4  ...                         NaN                       NaT
#
#   Theorical payment amount 4 Theorical payment date 5  \
# 0                        NaN                      NaT
# 1                        NaN                      NaT
# 2                        NaN                      NaT
# 3                        NaN                      NaT
# 4                        NaN                      NaT
#
#   Theorical payment amount 5              Created On      Last Modified Date  \
# 0                        NaN 2023-10-11 10:59:07.310 2023-10-11 10:59:07.310
# 1                        NaN 2023-10-11 10:55:50.773 2023-10-11 10:55:50.773
# 2                        NaN 2023-10-11 08:53:52.533 2023-10-11 08:54:37.860
# 3                        NaN 2023-10-11 08:42:41.140 2023-10-11 08:42:41.140
# 4                        NaN 2023-10-10 15:54:31.827 2023-10-10 15:56:12.527
#
#   Actual Close Date         Assignment Date Branch ID
# 0               NaT 2023-10-11 10:58:16.137      SDLV
# 1               NaT 2023-10-11 10:53:26.857      SDLV
# 2               NaT 2023-10-11 08:52:52.257      SDLV
# 3               NaT 2023-10-11 08:41:27.513      SDLV
# 4               NaT 2023-10-10 15:53:17.550      SDLV
#
# [5 rows x 43 columns]

# %%
opportunities.shape
# Out:
# (5986, 43)

# %%
nonstockitems.head()
# Out:
#   Inventory ID                                     Description EN  \
# 0      CAMP001  Henri LACHMANN room (1/2 day), fully equipped:...
# 1      CAMP002  Salle Henri LACHMANN, fully-equipped room: vid...
# 2      CAMP003  Salle Olympique Lyonnais (1/2 day), fully equi...
# 3      CAMP004  Salle Olympique Lyonnais, fully equipped room:...
# 4      CAMP005  Gol de Letra room (1/2 day), fully equipped: v...
#
#   Posting Class Tax Category Base Unit Item Status              Created On  \
# 0        CAMPUS       TVA 20    DEMI J      Active 2021-02-12 02:58:56.990
# 1        CAMPUS       TVA 20      JOUR      Active 2021-02-12 02:58:57.430
# 2        CAMPUS       TVA 20    DEMI J      Active 2021-02-12 02:58:57.557
# 3        CAMPUS       TVA 20      JOUR      Active 2021-02-12 02:58:57.683
# 4        CAMPUS       TVA 20    DEMI J      Active 2021-02-12 02:58:57.810
#
#          Last Modified On  Default Price
# 0 2022-08-23 13:01:01.627          126.0
# 1 2022-08-23 13:01:17.627          214.2
# 2 2022-08-23 13:01:28.037          252.0
# 3 2022-08-23 13:01:47.147          415.8
# 4 2022-08-23 13:01:55.207          252.0

# %%
nonstockitems.shape
# Out:
# (97, 9)

# %%
itemsandopp.head()
# Out:
#    Opportunity ID  Line Nbr. Inventory ID    Year  Unit Price  Quantity  \
# 0            6387        1.0      EVEN001  2023.0      9000.0       1.0
# 1            6386        1.0      EVEN001  2023.0      9000.0       1.0
# 2            6385        1.0       DONPAR  2023.0       140.0       1.0
# 3            6384        1.0       DONPAR  2023.0       350.0       1.0
# 4            6383        1.0       DONPAR  2023.0       120.0       1.0
#
#      UOM  Ext. Price Currency  Discount Amount  Discount, % Funded Program  \
# 0  PIECE      9000.0      EUR              0.0          0.0  Non specified
# 1  PIECE      9000.0      EUR              0.0          0.0  Non specified
# 2  PIECE       140.0      EUR              0.0          0.0  Non specified
# 3  PIECE       350.0      EUR              0.0          0.0  Non specified
# 4  PIECE       120.0      EUR              0.0          0.0  Non specified
#
#   Free Item Tax Category
# 0     False         TVA0
# 1     False         TVA0
# 2     False         TVA0
# 3     False         TVA0
# 4     False         TVA0

# %%
itemsandopp.shape
# Out:
# (7458, 14)

# %% [markdown]
# # Opportunities visualisation

# %%
opportunities.Stage.value_counts()
# Out:
# Won                  4102
# Oral agreement       1081
# Initial Prospect      545
# Dossier posed         118
# Advanced Prospect     106
# Lost                   34
# Name: Stage, dtype: int64

# %%
share_won = opportunities.Stage.value_counts().Won / opportunities.shape[0]
share_lost = opportunities.Stage.value_counts().Lost / opportunities.shape[0]
share_other = 1 - share_won - share_lost

# %%
opportunities_won = opportunities[opportunities.Stage == "Won"]
opportunities_lost = opportunities[opportunities.Stage == "Lost"]
opportunities_other = opportunities[~((opportunities.Stage == "Lost") | (opportunities.Stage == "Won")).values]

# %%
opportunities_won
# Out:
#       Opportunity ID Business Account  Contact ID Estimated Close Date Status  \
# 0               6387           C00037     35334.0           2023-11-27    New
# 1               6386           C01254     36240.0           2023-10-11    New
# 22              6365           C18115     46338.0           2023-10-25    Won
# 41              6346           C00510     36067.0           2023-11-10    New
# 49              6338           C00366     37931.0           2023-11-15    Won
# ...              ...              ...         ...                  ...    ...
# 5981               5           C00036         NaN           2020-01-01    Won
# 5982               4           C00024         NaN           2020-01-01    Won
# 5983               3           C00011         NaN           2020-01-01    Won
# 5984               2           C00331         NaN           2020-01-01    Won
# 5985               1           C00331         NaN           2020-01-01    Won
#
#      Stage  Probability  Estimated amount  Amount received  Difference  ...  \
# 0      Won          100           9000.00              NaN    -9000.00  ...
# 1      Won          100           9000.00              NaN    -9000.00  ...
# 22     Won          200            150.00              NaN     -150.00  ...
# 41     Won          100           1047.81              NaN    -1047.81  ...
# 49     Won          100            756.00              NaN     -756.00  ...
# ...    ...          ...               ...              ...         ...  ...
# 5981   Won          100           1059.00              NaN    -1059.00  ...
# 5982   Won          200           7500.00           7500.0        0.00  ...
# 5983   Won          100          35000.00              NaN   -35000.00  ...
# 5984   Won          100          20000.00              NaN   -20000.00  ...
# 5985   Won          100          10000.00              NaN   -10000.00  ...
#
#       Theorical payment amount 3  Theorical payment date 4  \
# 0                            NaN                       NaT
# 1                            NaN                       NaT
# 22                           NaN                       NaT
# 41                           NaN                       NaT
# 49                           NaN                       NaT
# ...                          ...                       ...
# 5981                         NaN                       NaT
# 5982                         NaN                       NaT
# 5983                         NaN                       NaT
# 5984                         NaN                       NaT
# 5985                         NaN                       NaT
#
#      Theorical payment amount 4 Theorical payment date 5  \
# 0                           NaN                      NaT
# 1                           NaN                      NaT
# 22                          NaN                      NaT
# 41                          NaN                      NaT
# 49                          NaN                      NaT
# ...                         ...                      ...
# 5981                        NaN                      NaT
# 5982                        NaN                      NaT
# 5983                        NaN                      NaT
# 5984                        NaN                      NaT
# 5985                        NaN                      NaT
#
#      Theorical payment amount 5              Created On  \
# 0                           NaN 2023-10-11 10:59:07.310
# 1                           NaN 2023-10-11 10:55:50.773
# 22                          NaN 2023-10-10 14:43:49.470
# 41                          NaN 2023-10-10 11:19:22.300
# 49                          NaN 2023-10-10 10:08:47.680
# ...                         ...                     ...
# 5981                        NaN 2021-02-12 06:10:11.650
# 5982                        NaN 2021-02-12 06:10:11.167
# 5983                        NaN 2021-02-12 06:10:09.633
# 5984                        NaN 2021-02-12 06:10:09.020
# 5985                        NaN 2021-02-12 06:10:08.500
#
#           Last Modified Date Actual Close Date         Assignment Date  \
# 0    2023-10-11 10:59:07.310               NaT 2023-10-11 10:58:16.137
# 1    2023-10-11 10:55:50.773               NaT 2023-10-11 10:53:26.857
# 22   2023-10-11 14:47:45.550        2023-10-11 2023-10-10 14:41:23.223
# 41   2023-10-10 11:19:22.300               NaT 2023-10-10 10:56:34.473
# 49   2023-10-10 11:18:18.663        2023-10-10 2023-10-10 10:07:16.487
# ...                      ...               ...                     ...
# 5981 2022-12-14 09:45:10.033        2022-12-14 2021-02-12 06:10:11.487
# 5982 2021-11-17 15:22:01.390        2021-11-17 2021-02-12 06:10:09.940
# 5983 2021-03-19 07:01:54.480        2021-03-19 2021-02-12 06:10:09.520
# 5984 2021-08-25 11:52:18.820        2021-08-25                     NaT
# 5985 2021-03-19 07:01:54.050        2021-03-19                     NaT
#
#      Branch ID
# 0         SDLV
# 1         SDLV
# 22        SDLV
# 41        SDLV
# 49        SDLV
# ...        ...
# 5981      SDLV
# 5982      SDLV
# 5983      SDLV
# 5984      SDLV
# 5985      SDLV
#
# [4102 rows x 43 columns]

# %%
plt.figure(figsize=(10,10))
plt.pie([share_won,share_lost,share_other],labels=("Opportunities Won","Opportunities Lost","Other"),autopct='%1.1f%%')
plt.title("Types of different opportunities")
plt.show()

# %%
opportunities_won.columns
# Out:
# Index(['Opportunity ID', 'Business Account', 'Contact ID',
#        'Estimated Close Date', 'Status', 'Stage', 'Probability',
#        'Estimated amount', 'Amount received', 'Difference', 'Owner Name',
#        'Follow-up with', 'Class ID', 'Class', 'Source', 'Source Campaign',
#        'Campaign Name', 'Programme financé', 'Action financée', 'Agreement',
#        'Signature date of the agreement', 'Agreement expiry date',
#        'Duration of agreement (months)',
#        'Deadline for submission of interim report', 'Final report deadline',
#        'Type de contrat', 'Type de financement', 'Zone SDLV',
#        'Theorical payment date 1', 'Theorical payment amount 1',
#        'Theorical payment date 2', 'Theorical payment amount 2',
#        'Theorical payment date 3', 'Theorical payment amount 3',
#        'Theorical payment date 4', 'Theorical payment amount 4',
#        'Theorical payment date 5', 'Theorical payment amount 5', 'Created On',
#        'Last Modified Date', 'Actual Close Date', 'Assignment Date',
#        'Branch ID'],
#       dtype='object')

# %%
set_won = set(opportunities_won["Opportunity ID"].values)

# %%
set_invoices  = set(invoices["Opportunity ID"].values)

# %%
opportunities_won["Amount received"] = opportunities_won["Amount received"].fillna(0)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
opportunities_won
# Out:
#       Opportunity ID Business Account  Contact ID Estimated Close Date Status  \
# 0               6387           C00037     35334.0           2023-11-27    New
# 1               6386           C01254     36240.0           2023-10-11    New
# 22              6365           C18115     46338.0           2023-10-25    Won
# 41              6346           C00510     36067.0           2023-11-10    New
# 49              6338           C00366     37931.0           2023-11-15    Won
# ...              ...              ...         ...                  ...    ...
# 5981               5           C00036         NaN           2020-01-01    Won
# 5982               4           C00024         NaN           2020-01-01    Won
# 5983               3           C00011         NaN           2020-01-01    Won
# 5984               2           C00331         NaN           2020-01-01    Won
# 5985               1           C00331         NaN           2020-01-01    Won
#
#      Stage  Probability  Estimated amount  Amount received  Difference  ...  \
# 0      Won          100           9000.00              0.0    -9000.00  ...
# 1      Won          100           9000.00              0.0    -9000.00  ...
# 22     Won          200            150.00              0.0     -150.00  ...
# 41     Won          100           1047.81              0.0    -1047.81  ...
# 49     Won          100            756.00              0.0     -756.00  ...
# ...    ...          ...               ...              ...         ...  ...
# 5981   Won          100           1059.00              0.0    -1059.00  ...
# 5982   Won          200           7500.00           7500.0        0.00  ...
# 5983   Won          100          35000.00              0.0   -35000.00  ...
# 5984   Won          100          20000.00              0.0   -20000.00  ...
# 5985   Won          100          10000.00              0.0   -10000.00  ...
#
#       Theorical payment amount 3  Theorical payment date 4  \
# 0                            NaN                       NaT
# 1                            NaN                       NaT
# 22                           NaN                       NaT
# 41                           NaN                       NaT
# 49                           NaN                       NaT
# ...                          ...                       ...
# 5981                         NaN                       NaT
# 5982                         NaN                       NaT
# 5983                         NaN                       NaT
# 5984                         NaN                       NaT
# 5985                         NaN                       NaT
#
#      Theorical payment amount 4 Theorical payment date 5  \
# 0                           NaN                      NaT
# 1                           NaN                      NaT
# 22                          NaN                      NaT
# 41                          NaN                      NaT
# 49                          NaN                      NaT
# ...                         ...                      ...
# 5981                        NaN                      NaT
# 5982                        NaN                      NaT
# 5983                        NaN                      NaT
# 5984                        NaN                      NaT
# 5985                        NaN                      NaT
#
#      Theorical payment amount 5              Created On  \
# 0                           NaN 2023-10-11 10:59:07.310
# 1                           NaN 2023-10-11 10:55:50.773
# 22                          NaN 2023-10-10 14:43:49.470
# 41                          NaN 2023-10-10 11:19:22.300
# 49                          NaN 2023-10-10 10:08:47.680
# ...                         ...                     ...
# 5981                        NaN 2021-02-12 06:10:11.650
# 5982                        NaN 2021-02-12 06:10:11.167
# 5983                        NaN 2021-02-12 06:10:09.633
# 5984                        NaN 2021-02-12 06:10:09.020
# 5985                        NaN 2021-02-12 06:10:08.500
#
#           Last Modified Date Actual Close Date         Assignment Date  \
# 0    2023-10-11 10:59:07.310               NaT 2023-10-11 10:58:16.137
# 1    2023-10-11 10:55:50.773               NaT 2023-10-11 10:53:26.857
# 22   2023-10-11 14:47:45.550        2023-10-11 2023-10-10 14:41:23.223
# 41   2023-10-10 11:19:22.300               NaT 2023-10-10 10:56:34.473
# 49   2023-10-10 11:18:18.663        2023-10-10 2023-10-10 10:07:16.487
# ...                      ...               ...                     ...
# 5981 2022-12-14 09:45:10.033        2022-12-14 2021-02-12 06:10:11.487
# 5982 2021-11-17 15:22:01.390        2021-11-17 2021-02-12 06:10:09.940
# 5983 2021-03-19 07:01:54.480        2021-03-19 2021-02-12 06:10:09.520
# 5984 2021-08-25 11:52:18.820        2021-08-25                     NaT
# 5985 2021-03-19 07:01:54.050        2021-03-19                     NaT
#
#      Branch ID
# 0         SDLV
# 1         SDLV
# 22        SDLV
# 41        SDLV
# 49        SDLV
# ...        ...
# 5981      SDLV
# 5982      SDLV
# 5983      SDLV
# 5984      SDLV
# 5985      SDLV
#
# [4102 rows x 43 columns]

# %%
plt.figure(figsize=(15,10))
plt.plot(opportunities_won["Estimated amount"].values)
plt.plot(opportunities_won["Amount received"].values)
plt.title("Difference between Amount received and Estimated amount")
plt.show()

# %% [markdown]
# ## Won opportunities

# %%
opportunities_won_withoutNan = opportunities_won.dropna(subset=["Amount received"])

# %%
expected_amount = opportunities_won_withoutNan["Estimated amount"].sum()
expected_amount
# Out:
# 82818645.82

# %%
amount_received = opportunities_won_withoutNan["Amount received"].sum()
amount_received
# Out:
# 40128738.3

# %%
opportunities_won_fill = opportunities_won.fillna(opportunities_won["Estimated amount"])

# %%
expected_amount_fill = opportunities_won_fill["Estimated amount"].sum()
expected_amount_fill
# Out:
# 82818645.82

# %%
amount_received_fill = opportunities_won_fill["Amount received"].sum()
amount_received_fill
# Out:
# 40128738.3

# %%
opportunities_won["Assignment Date"].min()
# Out:
# Timestamp('2021-02-12 06:10:09.520000')

# %%
client_id = opportunities_won["Contact ID"].values

# %%
client_id
# Out:
# array([35334., 36240., 46338., ...,    nan,    nan,    nan])

# %%
 opportunities_won["Type de financement"]
# Out:
# 0                  NaN
# 1                  NaN
# 22                 NaN
# 41      Fonctionnement
# 49                 NaN
#              ...
# 5981    Fonctionnement
# 5982    Fonctionnement
# 5983    Fonctionnement
# 5984    Investissement
# 5985    Fonctionnement
# Name: Type de financement, Length: 4102, dtype: object

# %%
plt.figure(figsize=(15,10))
plt.plot(opportunities_won["Created On"],opportunities_won["Amount received"])
plt.plot(opportunities_won["Created On"],opportunities_won["Estimated Amount"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Estimated Amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-b523625528a5> in <module>
#       1 plt.figure(figsize=(15,10))
#       2 plt.plot(opportunities_won["Created On"],opportunities_won["Amount received"])
# ----> 3 plt.plot(opportunities_won["Created On"],opportunities_won["Estimated Amount"])
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Estimated Amount'
