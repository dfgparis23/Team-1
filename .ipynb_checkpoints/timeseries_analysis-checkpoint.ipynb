# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

FILE_PATH = "../shared_data_read_only/"
FILES = ("consumer_price_index.xlsx","Contacts.xlsx","Invoice and Opportunities.xlsx",
         "Items and Opportunities.xlsx","Non-Stock Items.xlsx","Opportunities.xlsx")

plt.rc("figure",figsize=(25,12))

# %%
file_no = 2 # Invoice
df_invoice = pd.read_excel(f"{FILE_PATH}{FILES[file_no]}")
print(f"File : {FILES[file_no]}")
df_invoice.head()
# Out:
# File : Invoice and Opportunities.xlsx
#       Type Reference Nbr. Customer    Amount       Date  Opportunity ID
# 0  Invoice      FC0004608   C06507    5000.0 2023-10-10            4504
# 1  Invoice      FC0004607   C01388  241253.0 2023-10-09            1863
# 2  Invoice      FC0004605   C19104   83954.0 2023-10-06            5708
# 3  Invoice      FC0004600   C10528    3000.0 2023-06-23            5617
# 4  Invoice      FC0004598   C01196   54531.0 2023-10-09            5829

# %%
file_no = 4 # Invoice
df_class = pd.read_excel(f"{FILE_PATH}{FILES[file_no]}")
print(f"File : {FILES[file_no]}")
df_class.head()
# Out:
# File : Non-Stock Items.xlsx
#   Inventory ID                                     Description EN  \
# 0      CAMP001  Henri LACHMANN room (1/2 day), fully equipped:...
# 1      CAMP002  Salle Henri LACHMANN, fully-equipped room: vid...
# 2      CAMP003  Salle Olympique Lyonnais (1/2 day), fully equi...
# 3      CAMP004  Salle Olympique Lyonnais, fully equipped room:...
# 4      CAMP005  Gol de Letra room (1/2 day), fully equipped: v...
#
#   Posting Class Tax Category Base Unit Item Status              Created On  \
# 0        CAMPUS       TVA 20    DEMI J      Active 2021-02-12 02:58:56.990
# 1        CAMPUS       TVA 20      JOUR      Active 2021-02-12 02:58:57.430
# 2        CAMPUS       TVA 20    DEMI J      Active 2021-02-12 02:58:57.557
# 3        CAMPUS       TVA 20      JOUR      Active 2021-02-12 02:58:57.683
# 4        CAMPUS       TVA 20    DEMI J      Active 2021-02-12 02:58:57.810
#
#          Last Modified On  Default Price
# 0 2022-08-23 13:01:01.627          126.0
# 1 2022-08-23 13:01:17.627          214.2
# 2 2022-08-23 13:01:28.037          252.0
# 3 2022-08-23 13:01:47.147          415.8
# 4 2022-08-23 13:01:55.207          252.0

# %%
file_no = 3 # Invoice
df_item_inv = pd.read_excel(f"{FILE_PATH}{FILES[file_no]}")
print(f"File : {FILES[file_no]}")
df_item_inv.head()
# Out:
# File : Items and Opportunities.xlsx
#    Opportunity ID  Line Nbr. Inventory ID    Year  Unit Price  Quantity  \
# 0            6387        1.0      EVEN001  2023.0      9000.0       1.0
# 1            6386        1.0      EVEN001  2023.0      9000.0       1.0
# 2            6385        1.0       DONPAR  2023.0       140.0       1.0
# 3            6384        1.0       DONPAR  2023.0       350.0       1.0
# 4            6383        1.0       DONPAR  2023.0       120.0       1.0
#
#      UOM  Ext. Price Currency  Discount Amount  Discount, % Funded Program  \
# 0  PIECE      9000.0      EUR              0.0          0.0  Non specified
# 1  PIECE      9000.0      EUR              0.0          0.0  Non specified
# 2  PIECE       140.0      EUR              0.0          0.0  Non specified
# 3  PIECE       350.0      EUR              0.0          0.0  Non specified
# 4  PIECE       120.0      EUR              0.0          0.0  Non specified
#
#   Free Item Tax Category
# 0     False         TVA0
# 1     False         TVA0
# 2     False         TVA0
# 3     False         TVA0
# 4     False         TVA0

# %%
df_item_full = pd.merge(df_item[["Inventory ID","Posting Class"]],df_item_inv[["Inventory ID","Opportunity ID"]],on="Inventory ID")

df_result = pd.merge(df_invoice,df_item_full,on="Opportunity ID").drop_duplicates().reset_index(drop=True)

# %%
df_result
# Out:
#          Type Reference Nbr. Customer     Amount       Date  Opportunity ID  \
# 0     Invoice      FC0004608   C06507    5000.00 2023-10-10            4504
# 1     Invoice      FC0004607   C01388  241253.00 2023-10-09            1863
# 2     Invoice      FC0001908   C01388  643340.00 2022-03-21            1863
# 3     Invoice      FC0001883   C01388  643340.00 2021-03-21            1863
# 4     Invoice      FC0004605   C19104   83954.00 2023-10-06            5708
# ...       ...            ...      ...        ...        ...             ...
# 3602  Invoice      FC0000015   C00644      67.66 2021-03-01            1494
# 3603  Invoice      FC0000003   C00644      67.66 2021-03-15            1494
# 3604  Invoice      FC0000014   C00621  200000.00 2021-03-02              76
# 3605  Invoice      FC0000010   C00621  350000.00 2020-01-01              76
# 3606  Invoice      FC0000007   C00589    3000.00 2020-03-29            1056
#
#      Inventory ID Posting Class
# 0         MECENAT       MECENAT
# 1      PARTPUB005       PARTPUB
# 2      PARTPUB005       PARTPUB
# 3      PARTPUB005       PARTPUB
# 4         CAMP026        CAMPUS
# ...           ...           ...
# 3602     TAXEAPPR       TAXEAPP
# 3603     TAXEAPPR       TAXEAPP
# 3604      MECENAT       MECENAT
# 3605      MECENAT       MECENAT
# 3606      EVEN021         EVENT
#
# [3607 rows x 8 columns]

# %%
df_result['Posting Class'].unique()
# Out:
# array(['MECENAT', 'PARTPUB', 'CAMPUS', 'EVENT', 'DONPAR', 'TAXEAPP'],
#       dtype=object)

# %%
df = df_result.groupby(by=["Date"]).agg({"Opportunity ID":"count","Amount":'sum',"Reference Nbr.":"count"}).sort_index().loc["2021-01-01":]

# %%
df_invoice_grouped_day = df.resample("W").sum().fillna(0)["Reference Nbr."]
df_invoice_grouped_day
# Out:
# Date
# 2021-01-10     1
# 2021-01-17     6
# 2021-01-24     6
# 2021-01-31     4
# 2021-02-07     5
#               ..
# 2023-09-17    14
# 2023-09-24    24
# 2023-10-01    16
# 2023-10-08    14
# 2023-10-15     3
# Freq: W-SUN, Name: Reference Nbr., Length: 145, dtype: int64

# %%
decomposition = sm.tsa.seasonal_decompose(df_invoice_grouped_day, model='additive')
decomposition.plot()
plt.show()

# %% [markdown]
# # For MECENAT

# %%
# ['MECENAT', 'PARTPUB', 'CAMPUS', 'EVENT', 'DONPAR', 'TAXEAPP']

to_keep = 'MECENAT'

df = df_result[df_result['Posting Class']==to_keep].groupby(by=["Date"]).agg({"Opportunity ID":"count","Amount":'sum',"Reference Nbr.":"count"}).sort_index().loc["2021-01-01":]
df_grouped_weekly = df.resample("W").sum().fillna(0)["Reference Nbr."]
decomposition = sm.tsa.seasonal_decompose(df_grouped_weekly, model='additive')
decomposition.plot()
plt.show()

# %% [markdown]
# # For EVENT

# %%
# ['MECENAT', 'PARTPUB', 'CAMPUS', 'EVENT', 'DONPAR', 'TAXEAPP']

to_keep = 'CAMPUS'

df = df_result[df_result['Posting Class']==to_keep].groupby(by=["Date"]).agg({"Opportunity ID":"count","Amount":'sum',"Reference Nbr.":"count"}).sort_index().loc["2021-01-01":]
df_grouped_weekly = df.resample("W").sum().fillna(0)["Reference Nbr."]
decomposition = sm.tsa.seasonal_decompose(df_grouped_weekly, model='additive')
decomposition.plot()
plt.show()

# %% [markdown]
# # For DONPAR

# %%
to_keep = 'DONPAR'

df = df_result[df_result['Posting Class']==to_keep].groupby(by=["Date"]).agg({"Opportunity ID":"count","Amount":'sum',"Reference Nbr.":"count"}).sort_index().loc["2021-01-01":]
df_grouped_weekly = df.resample("W").sum().fillna(0)["Reference Nbr."]
decomposition = sm.tsa.seasonal_decompose(df_grouped_weekly, model='additive')
decomposition.plot()
plt.show()

# %% [markdown]
# # For PARTPUB

# %%
to_keep = 'PARTPUB'

df = df_result[df_result['Posting Class']==to_keep].groupby(by=["Date"]).agg({"Opportunity ID":"count","Amount":'sum',"Reference Nbr.":"count"}).sort_index().loc["2021-01-01":]
df_grouped_weekly = df.resample("W").sum().fillna(0)["Reference Nbr."]
decomposition = sm.tsa.seasonal_decompose(df_grouped_weekly, model='additive')
decomposition.plot()
plt.show()
